# %% [markdown]
# ## Algorithm Workbench

# %% [markdown]
# ### Problem 1
#
# ![image.png](attachment:04fa24c6-118e-42bf-8f4d-3eda17486729.png)
#
# #### High-Level Overview
#
# This question took me a while, mostly because I misread the question. After I understood it, I thought that it would be useful to add an of statement to make sure that all numbers used in the function would be valid. Then by adding break to the else statement, I can execute the print statement outside of the while loop.

# %%
#create an accumulator variable
product = 0
#create a while loop that runs as long as the product is less than 100
while product < 100:
    #ask the user for a number less than 10, since 10 x 10 = 100
    num = int(input("Enter a number less than 10: "))
    if num < 10:
        product = num * 10
        print(f"The product is {product}")
    else:
        break
#if the numbers product is greater than 100
print("The product is greater than or equal to 100")
# Out:
# Enter a number less than 10:  7
# The product is 70
# Enter a number less than 10:  8
# The product is 80
# Enter a number less than 10:  9
# The product is 90
# Enter a number less than 10:  100
# The product is greater than or equal to 100

# %% [markdown]
# ### Problem 4
#
# ![image.png](attachment:0f43c352-8325-4bfc-bea5-1dc2e0603ec1.png)
#
# #### High-Level Overview
#
# I thought that it would be easiest to use a for loop for this problem since it is a fixed number of iterations. I wasn't sure if the running total part meant that the total should be printed after each number input, that is what I did. It is important to make sure all numbers are available to use (float) and that the range is from 1 to 11 so it iterates 10 times.

# %%
# create an accumulator variable
accumulate = 0
# create a loop that asks the user for a number 10 times
for i in range(1,11):
    num = float(input("Enter a number: "))
    accumulate += num
    print(f"The total is {accumulate: .2f}")
# Out:
# Enter a number:  1
# The total is  1.00
# Enter a number:  2
# The total is  3.00
# Enter a number:  1
# The total is  4.00
# Enter a number:  5
# The total is  9.00
# Enter a number:  5
# The total is  14.00
# Enter a number:  6
# The total is  20.00
# Enter a number:  7
# The total is  27.00
# Enter a number:  2
# The total is  29.00
# Enter a number:  3
# The total is  32.00
# Enter a number:  6
# The total is  38.00

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Problem 1
#
# ![image.png](attachment:dc39d095-1d23-4e35-9c2e-3a9eae0a45da.png)
#
# #### High-Level Overview
#
# Using a for loop is best for this problem since iteration is a fixed number. Make sure to have an accumulator outside of the loop, then it is accumulating numbers(bugs) from the user). I wanted to try using the variable i from the for loop in the print statement to keep track of which day it is. If you do this and have your range is 5, make sure to add 1 to i, this is because the range of 5 starts at 0.

# %%
#we should start by including an accumulator variable since it is a running total 
totalbugs = 0
#now we should have a loop that iterates 5 times
for i in range(5):
    #ask the user how many bugs they collected that day
    bugs = int(input(f"How many bugs did you collect on day {i + 1}"))
    totalbugs += bugs
print(f"The total number of bugs collected was {totalbugs}")
# Out:
# How many bugs did you collect on day 1 32
# How many bugs did you collect on day 2 12
# How many bugs did you collect on day 3 482
# How many bugs did you collect on day 4 3
# How many bugs did you collect on day 5 16
# The total number of bugs collected was 545

# %% [markdown]
# ### Problem 4
#
# ![image.png](attachment:418ee60e-13f1-464a-a033-18c7996b8050.png)
#
# #### High-Level Overview
#
# For this question, you should ask the user for the hours and speed inputs. Then, you can use the hours input as the range for a for loop. By using the variable i in the for loop and adding 1, I can use it as the number of hours in the distance equation. Also, using this same principle, I can print which hour it is and what distance has been traveled.

# %%
#create a distance variable
distance = 0
#ask the user for the speed of the vehicle
speed = int(input("What is the speed of the vehicle in mph? "))
# ask the user for the amount of time passed, must be an integer value
hours = int(input("How many hours has it traveled? "))
#use a for loop that iterates the value of hours times
for i in range(hours):
    distance = (speed * (i + 1))
    print(f"Hour {i + 1}, distance traveled = {distance}")
# Out:
# What is the speed of the vehicle in mph?  40
# How many hours has it traveled?  3
# Hour 1, distance traveled = 40
# Hour 2, distance traveled = 80
# Hour 3, distance traveled = 120

# %% [markdown]
# ### Problem 13
#
# ![image.png](attachment:a98cbf75-bcc0-42a6-82be-24acd8b38f87.png)
#
# #### High-Level Overview
#
# This problem took me a minute to figure out. After some time, I found that the outer loop controls rows and the inner loop controls columns. By adding the empty print statement at the end of the inner loop causes the line to drop down. For this to work, you should add a space between each *, hence end=" ". By having a decreasing outer loop, the program will decrease the amount of stars printed in the inner loop.

# %%
# this should be a for loop that has a decreasing value
# The outer loop controls how many rows will be printed
# The inner loop controls how many * will be printed in that row
for i in range(7,0,-1):
    for j in range(i):
        print("*", end=" ")
    print()
# Out:
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# ### Problem 14
#
# ![image.png](attachment:c0a9e19a-cd96-4dc4-9e89-fa3fba0c4b08.png)
#
# #### High-Level Overview
#
# For this problem, the loop is increasing in value, so it should be from 1 to a number(8) to iterate 7 times. Then, the outer loop prints the first "#" at the beginning of each row, the inner loop prints spaces for each value in that row. At the end of the inner loop, the second "#" prints and then the empty print statements moves it to the next line.

# %%
#this problem is a nested for loop
#outer loop controls the rows
for y in range(1,7):
    print("#", end=" ")
    #inner loop controls the amount of times something will be printed in each row
    for x in range(1,y):
        print(" ", end=" ")
    #This will print the second ("#") at the end of the inner loop then move down to the next line.
    print("#")
    print()
# Out:
# # #
#
# #   #
#
# #     #
#
# #       #
#
# #         #
#
# #           #
