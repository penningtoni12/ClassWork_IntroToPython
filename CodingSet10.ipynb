# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Problem 3
#
# ![image.png](attachment:392a5707-55e7-4a3b-b4e9-8ffa6c2aa314.png)
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*

# %%
import personalInfo
# Import the class made
def main():
    #create 3 instances of the class
    person1 = personalInfo.Personal_info("Jane Doe", "123 Jolly ln", "123-456-7897")
    person2 = personalInfo.Personal_info("Super-Man", "456 Krypton", "654-857-9825")
    person3 = personalInfo.Personal_info("Scooby-Doo", "6541 Mysterymobile rd", "000-456-MYSTERY")
    #print the data stored in the objects
    print(f'Person1: {person1.get_name()}, {person1.get_address()}, {person1.get_phone()}')
    print(f'Person2: {person2.get_name()}, {person2.get_address()}, {person2.get_phone()}')
    #testing the mutator methods
    person3.set_address("Shaggy's Shack")
    print(f'Person3: {person3.get_name()}, {person3.get_address()}, {person3.get_phone()}')

main()
# Out:
# Person1: Jane Doe, 123 Jolly ln, 123-456-7897
# Person2: Super-Man, 456 Krypton, 654-857-9825
# Person1: Scooby-Doo, Shaggy's Shack, 000-456-MYSTERY

# %% [markdown]
# ### Problem 4
#
# ![image.png](attachment:b39483da-63e4-4e7e-b0b1-d2e553e0349d.png)
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*

# %%
import employee
#import the class we just made ^

# make a main funation
def main():
    employee1 = employee.Employee("Susan Meyers", "47899", "Accounting", "Vice President")
    employee2 = employee.Employee("Mark Jones", "39119", "IT", "Programmer")
    employee3 = employee.Employee("Joy Rogers", "81774", "Manufacturing", "Engineer")

    employee1.display_employee()
    employee2.display_employee()
    employee3.display_employee()

if __name__ == "__main__":
    main()
# Out:
# Susan Meyers, ID: 47899, Department: Accounting, Job Title: Vice President.
# Mark Jones, ID: 39119, Department: IT, Job Title: Programmer.
# Joy Rogers, ID: 81774, Department: Manufacturing, Job Title: Engineer.
