# %% [markdown]
# # Chapter 11 Coding Set
#
# Work completed bIan Penningtone].
#
# **IMPORTANT: Remember to screen record ALL of your work on at least one problem. You must turn off the generative AI code-completion for this problem, as this problem is preparation for our final exam practical. You can turn off generative AI code-completion within Colab by tapping/clicking the settings icon in the upper right, tapping/clicking the AI Assistance section, and then deselecting "Consented to use generative AI features" and selecting "Hide generative AI features" (these settings may be returned to their previous states once you've completed this problem).**
#
# **If you start to struggle with a problem for an extended period of time, remember you can go comment on two other submissions now (seeing other student work helps), or you can post in our discussion forum for questions, which can also earn you extra credit.**

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Problem 1
# ![image.png](attachment:70732f3c-4b9d-48c3-9086-c4bd390d90ba.png)ow.*
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*

# %%
# import the subclass
import productionworker

# define a main function
def main():
    # I want to try allowing user input to the creation of the objects using the classes
    employee_name = input("What is the employee's name? ")
    employee_number = input("what is the employee's number? ")
    employee_shift = int(input("What shift does the employee work? "))
    employee_pay = input("What is the employee's hourly rate of pay? ")

    # create a function using the user's inputs
    employee1 = productionworker.ProductionWorker(employee_name, employee_number, employee_shift, employee_pay)
    print(employee1.get_shift())
    print(employee1.get_name())
    print(employee1.get_number())
    print(employee1.get_shift())

if __name__ == "__main__":
    main()
# Out:
# What is the employee's name?  john
# what is the employee's number?  54654
# What shift does the employee work?  1
# What is the employee's hourly rate of pay?  14.36
# day shift (1)
# john
# 54654
# day shift (1)

# %% [markdown]
# ### Problem 2
# ![image.png](attachment:85405850-a84d-4a5c-854f-6ccd3ad586b4.png)ow.*
#
# #### High-Level Overview
#
# *In two to three sentences at minimum, walk through your general approach to the problem and identify any particular issues you had.*
